# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision.datasets import FashionMNIST
from torchvision.transforms import ToTensor
from dataclasses import dataclass
import numpy as np
from torch.optim.sgd import SGD
from torch.optim.lr_scheduler import ExponentialLR
import tqdm
import wandb

@dataclass
class TrainConfig:
    """
    Dataclass for storing training configuration.
    
    Attributes:
        lr (float): Learning rate for the optimizer.
        eval_every (int): Frequency of evaluation during training.
        total_iterations (int): Total number of training iterations.
        scheduler_type (str): Type of learning rate scheduler.
        model_type (str): Type of model architecture.
        optimizer_type (str): Type of optimizer to use.
        gamma (float): Decay factor for ExponentialLR scheduler.
    """
    lr: float = 0.1
    eval_every: int = 10
    total_iterations: int = 3000
    scheduler_type: str = "none"
    model_type: str = "batch_norm"
    optimizer_type: str = "sgd"
    gamma: float = 0.99  # Used for ExponentialLR if scheduler_type is "exp"

def set_seed(seed: int) -> None:
    """
    Set seed for reproducibility.

    Args:
        seed (int): Seed value.
    """
    torch.cuda.manual_seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)

def get_datasets() -> tuple:
    """
    Load the FashionMNIST dataset.

    Returns:
        tuple: Train and test datasets.
    """
    train_dataset = FashionMNIST(root='./data', train=True, download=True, transform=ToTensor())
    test_dataset = FashionMNIST(root='./data', train=False, download=True, transform=ToTensor())
    return train_dataset, test_dataset

class GenericModel(nn.Module):
    """
    A generic neural network model for classification.

    Args:
        num_classes (int): Number of output classes.
        model_type (str): Type of model architecture.
    """
    def __init__(self, num_classes=10, model_type="batch_norm"):
        super().__init__()
        hidden_dim = 512
        self.model_type = model_type
        self.net = nn.Sequential(
            nn.Linear(in_features=28*28, out_features=hidden_dim),
            nn.ReLU(),
            nn.BatchNorm1d(num_features=hidden_dim) if model_type == "batch_norm" else nn.Identity(),
            nn.Linear(in_features=hidden_dim, out_features=num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Forward pass of the model.

        Args:
            x (torch.Tensor): Input tensor.
        Returns:
            torch.Tensor: Output tensor.
        """
        x = x.reshape((-1, 28*28))
        return self.net(x)

def get_optimizer(model: nn.Module, config: TrainConfig) -> optim.Optimizer:
    """
    Get the optimizer based on configuration.

    Args:
        model (nn.Module): Model instance.
        config (TrainConfig): Training configuration.
    Returns:
        optim.Optimizer: Optimizer instance.
    """
    if config.optimizer_type == "sgd":
        return SGD(model.parameters(), lr=config.lr)
    elif config.optimizer_type == "adam":
        return optim.Adam(model.parameters(), lr=config.lr)
    else:
        raise ValueError(f"Unknown optimizer type: {config.optimizer_type}")

def get_scheduler(optimizer: optim.Optimizer, config: TrainConfig):
    """
    Get the learning rate scheduler based on configuration.

    Args:
        optimizer (optim.Optimizer): Optimizer instance.
        config (TrainConfig): Training configuration.
    Returns:
        optim.lr_scheduler: Scheduler instance or None.
    """
    if config.scheduler_type == "exp":
        return ExponentialLR(optimizer, gamma=config.gamma)
    elif config.scheduler_type == "none":
        return None
    else:
        raise ValueError(f"Unknown scheduler type: {config.scheduler_type}")

def calculate_accuracy(y_pred: torch.Tensor, y_true: torch.Tensor) -> float:
    """
    Calculate the accuracy of predictions.

    Args:
        y_pred (torch.Tensor): Predicted outputs.
        y_true (torch.Tensor): True labels.
    Returns:
        float: Accuracy value.
    """
    _, predicted = torch.max(y_pred, 1)
    correct = (predicted == y_true).float().sum()
    accuracy = correct / y_true.shape[0]
    return accuracy.item()

def train_loop(
    model: nn.Module,
    X_train: torch.Tensor,
    y_train: torch.Tensor,
    X_val: torch.Tensor,
    y_val: torch.Tensor,
    config: TrainConfig,
    run_name: str | None = None,
    group: str | None = None,
    best_metrics: dict = None
) -> None:
    """
    Main training loop for the model.

    Args:
        model (nn.Module): Model to be trained.
        X_train (torch.Tensor): Training data.
        y_train (torch.Tensor): Training labels.
        X_val (torch.Tensor): Validation data.
        y_val (torch.Tensor): Validation labels.
        config (TrainConfig): Training configuration.
        run_name (str | None): WandB run name.
        group (str | None): Group name for wandb to group runs.
        best_metrics (dict): Dictionary to store the best test accuracy and corresponding configurations.
    """
    wandb.init(
        project="model_train_fashion_mnist",
        notes="version2",
        name=run_name,
        group=group,
        config=config
    )
    optimizer = get_optimizer(model, config)
    scheduler = get_scheduler(optimizer, config)
    model.to(device).train()

    for i in tqdm.trange(config.total_iterations):
        optimizer.zero_grad()
        loss = F.cross_entropy(model(X_train.to(device)), y_train.to(device))
        loss.backward()
        optimizer.step()
        
        metrics = {"iteration": i, "loss_train": loss.detach().cpu().item()}

        if (i + 1) % config.eval_every == 0:
            with torch.no_grad():
                model.to(device).eval()
                loss_val = F.cross_entropy(model(X_val.to(device)), y_val.to(device))
                model.train()
                metrics.update({"loss_val": loss_val.detach().cpu().item()})

        if scheduler:
            scheduler.step()
            metrics.update({"lr": scheduler.get_last_lr()[0]})
        else:
            metrics.update({"lr": config.lr})

        wandb.log(metrics)
    
    wandb.finish()

    # Evaluate test accuracy after training
    with torch.no_grad():
        model.to(device).eval()
        test_accuracy = calculate_accuracy(model(X_val.to(device)), y_val.to(device))
    
    # Update best_metrics if current run's test accuracy is the best
    if best_metrics["best_accuracy"] < test_accuracy:
        best_metrics["best_accuracy"] = test_accuracy
        best_metrics["best_lr"] = config.lr
        best_metrics["best_total_iterations"] = config.total_iterations

# Main execution
seed = 0
set_seed(seed)
train_dataset, test_dataset = get_datasets()

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

X_train = train_dataset.data.float().to(device)
y_train = train_dataset.targets.to(device)
X_test = test_dataset.data.float().to(device)
y_test = test_dataset.targets.to(device)

num_classes = 10  # Number of classes in FashionMNIST

learning_rates = [0.01, 0.1, 1.0, 2.0]
total_iterations_list = [100, 130, 500, 1000]
group_name = "lr_iterations_comparison"

best_metrics = {"best_accuracy": 0.0, "best_lr": 0.0, "best_total_iterations": 0}

for lr in learning_rates:
    for total_iterations in total_iterations_list:
        config = TrainConfig(eval_every=20, lr=lr, total_iterations=total_iterations, scheduler_type="exp", model_type="batch_norm", optimizer_type="sgd")
        model = GenericModel(num_classes=num_classes, model_type=config.model_type)
        run_name = f"lr_{lr}_iterations_{total_iterations}"
        train_loop(model, X_train, y_train, X_test, y_test, config=config, run_name=run_name, group=group_name, best_metrics=best_metrics)

        accuracy = calculate_accuracy(model(X_test.to(device)), y_test.to(device))
        print(f"Run: {run_name}, Test Accuracy: {accuracy:.4f}")

print(f"Best Test Accuracy: {best_metrics['best_accuracy']:.4f} with lr={best_metrics['best_lr']} and total_iterations={best_metrics['best_total_iterations']}")
# Out:
# Using device: cuda
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155419-pe3e6v1t</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/pe3e6v1t' target="_blank">lr_0.01_iterations_100</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/pe3e6v1t' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/pe3e6v1t</a>
# 100%|██████████| 100/100 [00:03<00:00, 27.03it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>loss_train</td><td>█▆▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▃▂▁</td></tr><tr><td>lr</td><td>███▇▇▇▆▆▆▆▆▆▆▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>99</td></tr><tr><td>loss_train</td><td>0.62582</td></tr><tr><td>loss_val</td><td>0.64527</td></tr><tr><td>lr</td><td>0.00366</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.01_iterations_100</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/pe3e6v1t' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/pe3e6v1t</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155419-pe3e6v1t/logs</code>
# Run: lr_0.01_iterations_100, Test Accuracy: 0.7899
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155430-ee62rz7u</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/ee62rz7u' target="_blank">lr_0.01_iterations_130</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/ee62rz7u' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/ee62rz7u</a>
# 100%|██████████| 130/130 [00:04<00:00, 26.70it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss_train</td><td>█▇▅▄▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▃▂▁▁</td></tr><tr><td>lr</td><td>██▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>129</td></tr><tr><td>loss_train</td><td>0.60745</td></tr><tr><td>loss_val</td><td>0.63669</td></tr><tr><td>lr</td><td>0.00271</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.01_iterations_130</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/ee62rz7u' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/ee62rz7u</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155430-ee62rz7u/logs</code>
# Run: lr_0.01_iterations_130, Test Accuracy: 0.7925
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155442-hb6is3oq</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hb6is3oq' target="_blank">lr_0.01_iterations_500</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hb6is3oq' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hb6is3oq</a>
# 100%|██████████| 500/500 [00:19<00:00, 26.04it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>loss_train</td><td>█▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▆▆▅▅▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>499</td></tr><tr><td>loss_train</td><td>0.55945</td></tr><tr><td>loss_val</td><td>0.58343</td></tr><tr><td>lr</td><td>7e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.01_iterations_500</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hb6is3oq' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hb6is3oq</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155442-hb6is3oq/logs</code>
# Run: lr_0.01_iterations_500, Test Accuracy: 0.8073
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155509-mwmba4iq</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/mwmba4iq' target="_blank">lr_0.01_iterations_1000</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/mwmba4iq' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/mwmba4iq</a>
# 100%|██████████| 1000/1000 [00:37<00:00, 26.55it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss_train</td><td>█▇▇▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▇▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>999</td></tr><tr><td>loss_train</td><td>0.56371</td></tr><tr><td>loss_val</td><td>0.58734</td></tr><tr><td>lr</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.01_iterations_1000</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/mwmba4iq' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/mwmba4iq</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155509-mwmba4iq/logs</code>
# Run: lr_0.01_iterations_1000, Test Accuracy: 0.8078
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155554-3cw4bc9a</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3cw4bc9a' target="_blank">lr_0.1_iterations_100</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3cw4bc9a' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3cw4bc9a</a>
# 100%|██████████| 100/100 [00:03<00:00, 27.02it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>loss_train</td><td>█▆▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▄▂▂▁</td></tr><tr><td>lr</td><td>████▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>99</td></tr><tr><td>loss_train</td><td>0.37255</td></tr><tr><td>loss_val</td><td>0.41627</td></tr><tr><td>lr</td><td>0.0366</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.1_iterations_100</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3cw4bc9a' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3cw4bc9a</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155554-3cw4bc9a/logs</code>
# Run: lr_0.1_iterations_100, Test Accuracy: 0.8551
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155605-e70vt0ge</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/e70vt0ge' target="_blank">lr_0.1_iterations_130</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/e70vt0ge' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/e70vt0ge</a>
# 100%|██████████| 130/130 [00:04<00:00, 27.12it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>loss_train</td><td>█▆▇▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▃▂▁▁</td></tr><tr><td>lr</td><td>███▇▇▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>129</td></tr><tr><td>loss_train</td><td>0.36247</td></tr><tr><td>loss_val</td><td>0.41691</td></tr><tr><td>lr</td><td>0.02708</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.1_iterations_130</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/e70vt0ge' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/e70vt0ge</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155605-e70vt0ge/logs</code>
# Run: lr_0.1_iterations_130, Test Accuracy: 0.8543
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155617-q7u8lsfe</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/q7u8lsfe' target="_blank">lr_0.1_iterations_500</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/q7u8lsfe' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/q7u8lsfe</a>
# 100%|██████████| 500/500 [00:18<00:00, 26.54it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>loss_train</td><td>█▆▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▇▆▆▅▅▅▅▄▄▄▄▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>499</td></tr><tr><td>loss_train</td><td>0.33425</td></tr><tr><td>loss_val</td><td>0.39144</td></tr><tr><td>lr</td><td>0.00066</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.1_iterations_500</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/q7u8lsfe' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/q7u8lsfe</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155617-q7u8lsfe/logs</code>
# Run: lr_0.1_iterations_500, Test Accuracy: 0.8628
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155643-hd9g77k1</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hd9g77k1' target="_blank">lr_0.1_iterations_1000</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hd9g77k1' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hd9g77k1</a>
# 100%|██████████| 1000/1000 [00:37<00:00, 26.49it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>loss_train</td><td>█▆▆▄▄▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▆▅▅▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>999</td></tr><tr><td>loss_train</td><td>0.33209</td></tr><tr><td>loss_val</td><td>0.38695</td></tr><tr><td>lr</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_0.1_iterations_1000</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hd9g77k1' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/hd9g77k1</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155643-hd9g77k1/logs</code>
# Run: lr_0.1_iterations_1000, Test Accuracy: 0.8630
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155728-0gr8lvbv</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/0gr8lvbv' target="_blank">lr_1.0_iterations_100</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/0gr8lvbv' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/0gr8lvbv</a>
# 100%|██████████| 100/100 [00:03<00:00, 27.36it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>loss_train</td><td>▃▂█▅▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▂▁▁▁</td></tr><tr><td>lr</td><td>███▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>99</td></tr><tr><td>loss_train</td><td>0.34796</td></tr><tr><td>loss_val</td><td>0.43367</td></tr><tr><td>lr</td><td>0.36603</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_1.0_iterations_100</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/0gr8lvbv' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/0gr8lvbv</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155728-0gr8lvbv/logs</code>
# Run: lr_1.0_iterations_100, Test Accuracy: 0.8495
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155739-wwhdypu1</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/wwhdypu1' target="_blank">lr_1.0_iterations_130</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/wwhdypu1' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/wwhdypu1</a>
# 100%|██████████| 130/130 [00:04<00:00, 27.62it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>loss_train</td><td>▅█▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▃▂▁▁▁</td></tr><tr><td>lr</td><td>██▇▇▇▇▆▆▆▅▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>129</td></tr><tr><td>loss_train</td><td>0.34138</td></tr><tr><td>loss_val</td><td>0.43178</td></tr><tr><td>lr</td><td>0.27075</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_1.0_iterations_130</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/wwhdypu1' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/wwhdypu1</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155739-wwhdypu1/logs</code>
# Run: lr_1.0_iterations_130, Test Accuracy: 0.8575
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155751-3yzlfxof</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3yzlfxof' target="_blank">lr_1.0_iterations_500</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3yzlfxof' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3yzlfxof</a>
# 100%|██████████| 500/500 [00:18<00:00, 27.14it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>loss_train</td><td>█▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▇▇▅▅▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>499</td></tr><tr><td>loss_train</td><td>0.29299</td></tr><tr><td>loss_val</td><td>0.37236</td></tr><tr><td>lr</td><td>0.00657</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_1.0_iterations_500</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3yzlfxof' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/3yzlfxof</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155751-3yzlfxof/logs</code>
# Run: lr_1.0_iterations_500, Test Accuracy: 0.8715
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155817-7zsykp8p</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/7zsykp8p' target="_blank">lr_1.0_iterations_1000</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/7zsykp8p' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/7zsykp8p</a>
# 100%|██████████| 1000/1000 [00:36<00:00, 27.20it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▁▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss_train</td><td>█▆▅▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▆▅▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>999</td></tr><tr><td>loss_train</td><td>0.28033</td></tr><tr><td>loss_val</td><td>0.43588</td></tr><tr><td>lr</td><td>4e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_1.0_iterations_1000</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/7zsykp8p' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/7zsykp8p</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155817-7zsykp8p/logs</code>
# Run: lr_1.0_iterations_1000, Test Accuracy: 0.8741
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155901-nmro73gy</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/nmro73gy' target="_blank">lr_2.0_iterations_100</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/nmro73gy' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/nmro73gy</a>
# 100%|██████████| 100/100 [00:03<00:00, 27.55it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>loss_train</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▃▁▁▁</td></tr><tr><td>lr</td><td>████▇▇▇▇▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>99</td></tr><tr><td>loss_train</td><td>0.38172</td></tr><tr><td>loss_val</td><td>0.43921</td></tr><tr><td>lr</td><td>0.73206</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_2.0_iterations_100</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/nmro73gy' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/nmro73gy</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155901-nmro73gy/logs</code>
# Run: lr_2.0_iterations_100, Test Accuracy: 0.8440
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155912-2qnke0f9</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/2qnke0f9' target="_blank">lr_2.0_iterations_130</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/2qnke0f9' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/2qnke0f9</a>
# 100%|██████████| 130/130 [00:04<00:00, 27.57it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>loss_train</td><td>▂█▆▄▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▅▃▂▁▁</td></tr><tr><td>lr</td><td>███▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>129</td></tr><tr><td>loss_train</td><td>0.36109</td></tr><tr><td>loss_val</td><td>0.42719</td></tr><tr><td>lr</td><td>0.54151</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_2.0_iterations_130</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/2qnke0f9' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/2qnke0f9</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155912-2qnke0f9/logs</code>
# Run: lr_2.0_iterations_130, Test Accuracy: 0.8553
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155924-vxaxx3nw</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/vxaxx3nw' target="_blank">lr_2.0_iterations_500</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/vxaxx3nw' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/vxaxx3nw</a>
# 100%|██████████| 500/500 [00:18<00:00, 27.17it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>loss_train</td><td>▂█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▃▂▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>lr</td><td>█▇▇▇▇▆▅▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>499</td></tr><tr><td>loss_train</td><td>0.32005</td></tr><tr><td>loss_val</td><td>0.47733</td></tr><tr><td>lr</td><td>0.01314</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_2.0_iterations_500</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/vxaxx3nw' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/vxaxx3nw</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155924-vxaxx3nw/logs</code>
# Run: lr_2.0_iterations_500, Test Accuracy: 0.8675
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_155950-utq25jaa</code>
# Syncing run <strong><a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/utq25jaa' target="_blank">lr_2.0_iterations_1000</a></strong> to <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a>
#  View run at <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/utq25jaa' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/utq25jaa</a>
# 100%|██████████| 1000/1000 [00:37<00:00, 26.98it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>iteration</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>loss_train</td><td>██▆▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_val</td><td>█▆▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▇▆▆▆▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>iteration</td><td>999</td></tr><tr><td>loss_train</td><td>0.30578</td></tr><tr><td>loss_val</td><td>0.4208</td></tr><tr><td>lr</td><td>9e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lr_2.0_iterations_1000</strong> at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist/runs/utq25jaa' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist/runs/utq25jaa</a><br> View project at: <a href='https://wandb.ai/rncomp/model_train_fashion_mnist' target="_blank">https://wandb.ai/rncomp/model_train_fashion_mnist</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250106_155950-utq25jaa/logs</code>
# Run: lr_2.0_iterations_1000, Test Accuracy: 0.8687
# Best Test Accuracy: 0.8741 with lr=1.0 and total_iterations=1000
